# %%
import pandas as pd

# %%
commits = pd.read_json("https://data.wa.gov/resource/ds9y-yndq.json", orient="columns")

# %%
commits.head()
# Out:
#    :@computed_region_8ddd_yn5v  :@computed_region_fny7_vc3j  \
# 0                          4.0                          7.0
# 1                          4.0                          7.0
# 2                          4.0                          7.0
# 3                         20.0                          3.0
# 4                         20.0                          3.0
#
#    :@computed_region_x4ys_rtnd  ballot_number bonafide_type  \
# 0                       3009.0            NaN           NaN
# 1                       3009.0            NaN           NaN
# 2                       3009.0            NaN           NaN
# 3                        850.0            NaN  County Party
# 4                        850.0            NaN  County Party
#
#                                   cand_comm_location  \
# 0  {u'type': u'Point', u'coordinates': [-122.3354...
# 1  {u'type': u'Point', u'coordinates': [-122.3354...
# 2  {u'type': u'Point', u'coordinates': [-122.3354...
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 56 columns):
# :@computed_region_8ddd_yn5v    991 non-null float64
# :@computed_region_fny7_vc3j    991 non-null float64
# :@computed_region_x4ys_rtnd    999 non-null float64
# ballot_number                  24 non-null float64
# bonafide_type                  193 non-null object
# cand_comm_location             1000 non-null object
# candidate_committee_phone      938 non-null float64
# candidate_committee_status     268 non-null object
# candidate_email                268 non-null object
# committee_acronym              302 non-null object
# committee_address              1000 non-null object
# committee_city                 1000 non-null object
# committee_county               992 non-null object
# committee_email                861 non-null object
# committee_fax                  369 non-null float64
# committee_state                1000 non-null object
# ...

# %%
contribs = pd.read_json("https://data.wa.gov/resource/74eq-kst5.json", orient="columns")

# %%
contribs.head()
# Out:
#    amount cash_or_in_kind                        code  contributor_address  \
# 0   500.0            Cash  Political Action Committee       P. O. BOX 3236
# 1   100.0            Cash                  Individual        P. O. BOX 781
# 2    25.0            Cash                  Individual  4347 BIRKLAND RD NE
# 3    25.0            Cash                  Individual  4347 BIRKLAND RD NE
# 4   500.0            Cash  Political Action Committee          PO BOX 3236
#
#     contributor_city contributor_employer_city contributor_employer_name  \
# 0        OREGON CITY                       NaN                       NaN
# 1           WAUKESHA                       NaN                       NaN
# 2  BAINBRIDGE ISLAND                       NaN                       NaN
# 3  BAINBRIDGE ISLAND                       NaN                       NaN
# 4        OREGON CITY                       NaN                       NaN
#
#   contributor_employer_state                         contributor_name  \
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 35 columns):
# amount                        1000 non-null float64
# cash_or_in_kind               1000 non-null object
# code                          1000 non-null object
# contributor_address           927 non-null object
# contributor_city              934 non-null object
# contributor_employer_city     155 non-null object
# contributor_employer_name     164 non-null object
# contributor_employer_state    156 non-null object
# contributor_name              1000 non-null object
# contributor_occupation        195 non-null object
# contributor_state             967 non-null object
# contributor_zip               925 non-null object
# description                   14 non-null object
# election_year                 1000 non-null int64
# filer_id                      1000 non-null object
# filer_name                    1000 non-null object
# ...

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
contribs.amount.sum()
# Out:
# 408980909.53999996

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
smokeprop = props[props.prop_name == "PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE."]

# %%
smokeprop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# 74            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 75            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 76            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 77            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 78            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 74                456                 1381808
# ...

# %%
smokeprop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11 entries, 74 to 84
# Data columns (total 8 columns):
# ocd_prop_id               11 non-null object
# calaccess_prop_id         11 non-null int64
# ccdc_prop_id              11 non-null int64
# prop_name                 11 non-null object
# ccdc_committee_id         11 non-null int64
# calaccess_committee_id    11 non-null int64
# committee_name            11 non-null object
# committee_position        11 non-null object
# dtypes: int64(4), object(4)
# memory usage: 616.0+ bytes

# %%
smokemerge =pd.merge(smokeprop, contribs, on="calaccess_committee_id")

# %%
smokemerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 0 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     860 non-null object
# calaccess_prop_id               860 non-null int64
# ccdc_prop_id                    860 non-null int64
# prop_name                       860 non-null object
# ccdc_committee_id               860 non-null int64
# calaccess_committee_id          860 non-null int64
# committee_name_x                860 non-null object
# committee_position              860 non-null object
# committee_name_y                860 non-null object
# calaccess_filing_id             860 non-null int64
# date_received                   860 non-null object
# contributor_lastname            860 non-null object
# contributor_firstname           750 non-null object
# contributor_city                860 non-null object
# contributor_state               860 non-null object
# contributor_zip                 860 non-null object
# ...

# %%
smokemerge.contributor_city.value_counts()
# Out:
# SAN FRANCISCO        64
# SACRAMENTO           38
# OAKLAND              36
# LOS ANGELES          35
# SAN DIEGO            28
# BERKELEY             18
# DENVER               15
# NEW YORK             14
# SAN JOSE             14
# PALO ALTO            13
# WASHINGTON           12
# LANDERS              12
# SANTA MONICA         11
# SANTA CRUZ           11
# PASADENA             10
# VENTURA               9
# ALEXANDRIA            9
# WILMINGTON            8
# RANCHO SANTA FE       8
# IRVINE                8
# REDWOOD CITY          8
# FRESNO                8
# PACIFIC PALISADES     8
# EL CERRITO            7
# SUNNYVALE             7
# LAGUNA BEACH          7
# ARCADIA               7
# ALAMEDA               6
# ENCINITAS             6
# BOULDER               6
#                      ..
# STEVENSON RANCH       1
# BURBANK               1
# BOULEVARD             1
# PEBBLE BEACH          1
# EAST PALO ALTO        1
# MILLBRAE              1
# SAN MARINO            1
# ...

# %%
smokemerge.contributor_state.value_counts()
# Out:
# CA    693
# CO     25
# NY     18
# DC     12
# PA     12
# WA     10
# VA     10
# FL     10
# IL     10
# DE      9
# MO      6
# NV      6
# AZ      5
# MA      4
# TX      4
# OR      4
# OH      4
# MD      3
# MI      2
# OK      2
# BC      2
# AB      2
# RI      1
# AL      1
# GA      1
# NC      1
# LA      1
# ID      1
# CT      1
# Name: contributor_state, dtype: int64

# %%
smokemerge.amount.sum()
# Out:
# 35177017.640000001

# %%
smokemerge.amount.mean()
# Out:
# 40903.508883720933

# %%
outofstatesmoke = smokemerge[smokemerge.contributor_state != "CA"]

# %%
outofstatesmoke
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 4    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 5    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 9    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 20   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 44   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 52   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 57   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 61   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 62   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 63   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 106  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 134  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
instatesmoke = smokemerge[smokemerge.contributor_state == "CA"]

# %%
instatesmoke
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 7    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 8    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 10   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 11   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 12   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 13   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 14   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
instatesmoke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 693 entries, 0 to 857
# Data columns (total 20 columns):
# ocd_prop_id                     693 non-null object
# calaccess_prop_id               693 non-null int64
# ccdc_prop_id                    693 non-null int64
# prop_name                       693 non-null object
# ccdc_committee_id               693 non-null int64
# calaccess_committee_id          693 non-null int64
# committee_name_x                693 non-null object
# committee_position              693 non-null object
# committee_name_y                693 non-null object
# calaccess_filing_id             693 non-null int64
# date_received                   693 non-null object
# contributor_lastname            693 non-null object
# contributor_firstname           624 non-null object
# contributor_city                693 non-null object
# contributor_state               693 non-null object
# contributor_zip                 693 non-null object
# ...

# %%
instatesmoke.amount.sum()
# Out:
# 17491193.0

# %%
outofstatesmoke.amount.sum()
# Out:
# 17685824.640000001

# %%
smokemerge.committee_position.value_counts()
# Out:
# SUPPORT    762
# OPPOSE      98
# Name: committee_position, dtype: int64

# %%
opposesmoke = smokemerge[smokemerge.committee_position == "OPPOSE"]

# %%
opposesmoke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 98 entries, 261 to 859
# Data columns (total 20 columns):
# ocd_prop_id                     98 non-null object
# calaccess_prop_id               98 non-null int64
# ccdc_prop_id                    98 non-null int64
# prop_name                       98 non-null object
# ccdc_committee_id               98 non-null int64
# calaccess_committee_id          98 non-null int64
# committee_name_x                98 non-null object
# committee_position              98 non-null object
# committee_name_y                98 non-null object
# calaccess_filing_id             98 non-null int64
# date_received                   98 non-null object
# contributor_lastname            98 non-null object
# contributor_firstname           56 non-null object
# contributor_city                98 non-null object
# contributor_state               98 non-null object
# contributor_zip                 98 non-null object
# ...

# %%
opposesmoke.amount.value_counts()
# Out:
# 100.00        20
# 5000.00       14
# 500.00         7
# 200.00         6
# 1000.00        6
# 10000.00       5
# 250.00         5
# 25000.00       3
# 150.00         3
# 300.00         3
# 12500.00       2
# 2500.00        2
# 2000.00        2
# 400.00         2
# 14000.00       1
# 50.00          1
# 130.00         1
# 35000.00       1
# 200000.00      1
# 871.00         1
# 45000.00       1
# 408.64         1
# 225000.00      1
# 4185.00        1
# 400000.00      1
# 150000.00      1
# 18150.00       1
# 36000.00       1
# 6500.00        1
# 120000.00      1
# 1000000.00     1
# 817.00         1
# Name: amount, dtype: int64

# %%
supportsmoke = smokemerge[smokemerge.committee_position == "SUPPORT"]

# %%
supportsmoke
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 5    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 6    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 7    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 8    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 9    ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 10   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 11   ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# ...

# %%
bigdonorsoppose = opposesmoke[opposesmoke.amount > 100000]

# %%
bigdonorsoppose.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 308 to 840
# Data columns (total 20 columns):
# ocd_prop_id                     6 non-null object
# calaccess_prop_id               6 non-null int64
# ccdc_prop_id                    6 non-null int64
# prop_name                       6 non-null object
# ccdc_committee_id               6 non-null int64
# calaccess_committee_id          6 non-null int64
# committee_name_x                6 non-null object
# committee_position              6 non-null object
# committee_name_y                6 non-null object
# calaccess_filing_id             6 non-null int64
# date_received                   6 non-null object
# contributor_lastname            6 non-null object
# contributor_firstname           3 non-null object
# contributor_city                6 non-null object
# contributor_state               6 non-null object
# contributor_zip                 6 non-null object
# contributor_employer            0 non-null object
# ...

# %%
bigdonorsoppose.head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 308  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 310  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 312  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 837  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 308            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 310            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 312            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 837            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 839            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 308                459                 1382568
# ...

# %%
bigdonorsupport = supportsmoke[supportsmoke.amount > 100000]

# %%
bigdonorsoppose.head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 308  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 310  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 312  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 837  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 839  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#      ccdc_prop_id                                          prop_name  \
# 308            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 310            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 312            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 837            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 839            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 308                459                 1382568
# ...

# %%
supportsmoke.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 1  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 2  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 3  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 4  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#    ccdc_prop_id                                          prop_name  \
# 0            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 1            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 2            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 3            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
# 4            83  PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                456                 1381808
# ...

# %%
bigdonorsupport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 854
# Data columns (total 20 columns):
# ocd_prop_id                     51 non-null object
# calaccess_prop_id               51 non-null int64
# ccdc_prop_id                    51 non-null int64
# prop_name                       51 non-null object
# ccdc_committee_id               51 non-null int64
# calaccess_committee_id          51 non-null int64
# committee_name_x                51 non-null object
# committee_position              51 non-null object
# committee_name_y                51 non-null object
# calaccess_filing_id             51 non-null int64
# date_received                   51 non-null object
# contributor_lastname            51 non-null object
# contributor_firstname           19 non-null object
# contributor_city                51 non-null object
# contributor_state               51 non-null object
# contributor_zip                 51 non-null object
# ...

# %%
smokemerge.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending="False")
# Out:
#                                      committee_name_x       amount
# 6                         MOMS STRONG AGAINST PROP 64      6281.64
# 0          ADULT USE CAMPAIGN FOR PROPOSITION 64; THE     17089.00
# 5   MARIJUANA POLICY PROJECT OF CALIFORNIA, YES ON 64    739200.00
# 2   CALIFORNIANS FOR SENSIBLE REFORM, SPONSORED BY...    850000.00
# 1   CALIFORNIANS FOR RESPONSIBLE MARIJUANA REFORM,...    860470.00
# 8   PUBLIC AND MENTAL HEALTH ADVOCATES AGAINST 64,...   1130930.00
# 9   SAM ACTION, INC., A COMMITTEE AGAINST PROPOSIT...   1364000.00
# 7                              NEW APPROACH PAC (MPO)   3865000.00
# 3   DRUG POLICY ACTION - NON PROFIT 501C4, YES ON ...   4470000.00
# 4        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))   6140000.00
# 10  YES ON 64, CALIFORNIANS TO CONTROL, REGULATE A...  15734047.00

# %%
smokemerge.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname            contributor_lastname     amount
# 483                  SEAN  PARKER AND AFFILIATED ENTITIES  7250000.0
# 482                  SEAN                          PARKER  1500000.0
# 281                 JULIE                         SCHAUER  1364000.0
# 108                DANIEL                           LEWIS  1250000.0
# 194                 HENRY                   VAN AMERINGEN  1000000.0
# 405              NICHOLAS                        PRITZKER   900000.0
# 421                 PETER                           THIEL   300000.0
# 456                 ROGER                         JENKINS    75000.0
# 23                 ANGELA                          HOWARD    65000.0
# 322              LAWRENCE                            HESS    30000.0
# 221                 JASON                            POST    10000.0
# 460              ROGER B.                         MCNAMEE    10000.0
# 548           ZACHARY PYM                        WILLIAMS    10000.0
# ...

# %%
smokemerge.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname            contributor_lastname committee_position  \
# 483                  SEAN  PARKER AND AFFILIATED ENTITIES            SUPPORT
# 482                  SEAN                          PARKER            SUPPORT
# 281                 JULIE                         SCHAUER             OPPOSE
# 108                DANIEL                           LEWIS            SUPPORT
# 194                 HENRY                   VAN AMERINGEN            SUPPORT
# 405              NICHOLAS                        PRITZKER            SUPPORT
# 421                 PETER                           THIEL            SUPPORT
# 456                 ROGER                         JENKINS            SUPPORT
# 23                 ANGELA                          HOWARD            SUPPORT
# 322              LAWRENCE                            HESS            SUPPORT
# 221                 JASON                            POST            SUPPORT
# ...
