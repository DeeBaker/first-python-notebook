# %%
import pandas as pd

# %%
wacontribs = pd.read_csv("C:\Users\gheistGal\Campaign_Finance_Reporting_History.csv")

# %%
wacontribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477669 entries, 0 to 477668
# Data columns (total 25 columns):
# report_number           477669 non-null int64
# amends_report           49750 non-null float64
# amended_by_report       49758 non-null float64
# origin                  477669 non-null object
# filer_id                477669 non-null object
# election_year           477669 non-null int64
# type                    477669 non-null object
# filer_name              477669 non-null object
# first_name              273184 non-null object
# middle_initial          245490 non-null object
# last_name               477663 non-null object
# office                  273189 non-null object
# legislative_district    101187 non-null float64
# position                193726 non-null object
# party                   273069 non-null object
# ballot_number           11449 non-null float64
# for_or_against          32595 non-null object
# jurisdiction            284575 non-null object
# ...

# %%
wacontribs.head()
# Out:
#    report_number  amends_report  amended_by_report origin    filer_id  \
# 0      100115384            NaN                NaN     C3  PRIDC  661
# 1      100308648            NaN                NaN     C1  WOLFW  403
# 2      100308656            NaN                NaN     C1  ROSED  352
# 3      100308667            NaN                NaN     C1  ISAAR  801
# 4      100308677            NaN                NaN     C1  CAMMJ  363
#
#    election_year       type              filer_name first_name middle_initial  \
# 0           2008  Candidate       PRIDEMORE CRAIG A      CRAIG              A
# 1           2009  Candidate  WOLFINBARGER WILLIAM R    WILLIAM              R
# 2           2009  Candidate            ROSE DAVID W      DAVID              W
# 3           2009  Candidate      ISAACSON RICHARD M    RICHARD              M
# 4           2009  Candidate         CAMMACK JAMES G      JAMES              G
#
#   ...  ballot_number for_or_against               jurisdiction  \
# ...
