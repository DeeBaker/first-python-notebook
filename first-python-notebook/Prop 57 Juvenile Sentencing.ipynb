# %%
import pandas as pd

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head(3)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# 1                383                 1220380
# 2                384                 1282321
#
#                                       committee_name committee_position
# 0  YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...            SUPPORT
# 1  COMMUNITY COLLEGE FACILITY COALITION ISSUES CO...            SUPPORT
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 4.8+ KB

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.head(3)
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# 1                 MYRNA        SAN DIEGO                CA           92109
# 2                   LEO        ESCONDIDO                CA           92025
#
#        contributor_employer contributor_occupation  \
# 0                A NEW PATH     EXECUTIVE DIRECTOR
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 3.3+ MB

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
contribs.amount.sum()
# Out:
# 408980909.53999996

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
smokeprop = props[props.prop_name == "PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE."]

# %%
smokeprop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 35  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 36  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 37  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 38  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 39  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
#
#     ccdc_prop_id                                          prop_name  \
# 35            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 36            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 37            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 38            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 39            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 35                417                 1385745
# ...

# %%
smokeprop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 35 to 47
# Data columns (total 8 columns):
# ocd_prop_id               13 non-null object
# calaccess_prop_id         13 non-null int64
# ccdc_prop_id              13 non-null int64
# prop_name                 13 non-null object
# ccdc_committee_id         13 non-null int64
# calaccess_committee_id    13 non-null int64
# committee_name            13 non-null object
# committee_position        13 non-null object
# dtypes: int64(4), object(4)
# memory usage: 728.0+ bytes

# %%
smokemerge =pd.merge(smokeprop, contribs, on="calaccess_committee_id")

# %%
smokemerge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237 entries, 0 to 236
# Data columns (total 20 columns):
# ocd_prop_id                     237 non-null object
# calaccess_prop_id               237 non-null int64
# ccdc_prop_id                    237 non-null int64
# prop_name                       237 non-null object
# ccdc_committee_id               237 non-null int64
# calaccess_committee_id          237 non-null int64
# committee_name_x                237 non-null object
# committee_position              237 non-null object
# committee_name_y                237 non-null object
# calaccess_filing_id             237 non-null int64
# date_received                   237 non-null object
# contributor_lastname            237 non-null object
# contributor_firstname           117 non-null object
# contributor_city                237 non-null object
# contributor_state               237 non-null object
# contributor_zip                 237 non-null object
# ...

# %%
smokemerge.contributor_city.value_counts()
# Out:
# SACRAMENTO              31
# SAN FRANCISCO           12
# WASHINGTON              12
# OAKLAND                  9
# NEW YORK                 9
# LOS ANGELES              9
# WILMINGTON               8
# SAN DIEGO                8
# BAKERSFIELD              6
# PALMDALE                 4
# SANTA MONICA             4
# PASADENA                 3
# BEVERLY HILLS            3
# THOUSAND OAKS            3
# UPLAND                   2
# SANTA ROSA               2
# CHATSWORTH               2
# VISALIA                  2
# CAMARILLO                2
# OXNARD                   2
# ST. LOUIS                2
# DAVIS                    2
# PALO ALTO                2
# TORRANCE                 2
# WESTLAKE VILLAGE         2
# FRESNO                   2
# ENCINITAS                2
# ATWATER                  2
# SANTA ANA                2
# SONORA                   2
#                         ..
# GRANADA HILLS            1
# LA CANADA FLINTRIDGE     1
# RIVERSIDE                1
# ...

# %%
smokemerge.contributor_state.value_counts()
# Out:
# CA    205
# DC     12
# NY      9
# DE      8
# MO      2
# MA      1
# Name: contributor_state, dtype: int64

# %%
smokemerge.amount.sum()
# Out:
# 20097369.73

# %%
smokemerge.amount.mean()
# Out:
# 84799.028396624475

# %%
outofstatesmoke = smokemerge[smokemerge.contributor_state != "CA"]

# %%
outofstatesmoke
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 1    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 2    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 3    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 4    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 5    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 6    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 7    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 19   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 27   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 41   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 43   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# ...

# %%
instatesmoke = smokemerge[smokemerge.contributor_state == "CA"]

# %%
instatesmoke
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 8    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 9    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 10   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 11   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 12   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 13   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 14   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 15   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 16   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 17   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 18   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 20   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# ...

# %%
instatesmoke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 8 to 234
# Data columns (total 20 columns):
# ocd_prop_id                     205 non-null object
# calaccess_prop_id               205 non-null int64
# ccdc_prop_id                    205 non-null int64
# prop_name                       205 non-null object
# ccdc_committee_id               205 non-null int64
# calaccess_committee_id          205 non-null int64
# committee_name_x                205 non-null object
# committee_position              205 non-null object
# committee_name_y                205 non-null object
# calaccess_filing_id             205 non-null int64
# date_received                   205 non-null object
# contributor_lastname            205 non-null object
# contributor_firstname           117 non-null object
# contributor_city                205 non-null object
# contributor_state               205 non-null object
# contributor_zip                 205 non-null object
# ...

# %%
instatesmoke.amount.sum()
# Out:
# 11404408.609999999

# %%
outofstatesmoke.amount.sum()
# Out:
# 8692961.120000001

# %%
smokemerge.committee_position.value_counts()
# Out:
# OPPOSE     146
# SUPPORT     91
# Name: committee_position, dtype: int64

# %%
opposesmoke = smokemerge[smokemerge.committee_position == "OPPOSE"]

# %%
opposesmoke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 64 to 209
# Data columns (total 20 columns):
# ocd_prop_id                     146 non-null object
# calaccess_prop_id               146 non-null int64
# ccdc_prop_id                    146 non-null int64
# prop_name                       146 non-null object
# ccdc_committee_id               146 non-null int64
# calaccess_committee_id          146 non-null int64
# committee_name_x                146 non-null object
# committee_position              146 non-null object
# committee_name_y                146 non-null object
# calaccess_filing_id             146 non-null int64
# date_received                   146 non-null object
# contributor_lastname            146 non-null object
# contributor_firstname           93 non-null object
# contributor_city                146 non-null object
# contributor_state               146 non-null object
# contributor_zip                 146 non-null object
# ...

# %%
opposesmoke.amount.value_counts()
# Out:
#  100.0       45
#  500.0       21
#  1000.0      15
#  250.0       14
#  5000.0       9
#  2500.0       8
#  200.0        6
#  10000.0      6
#  150.0        4
#  100000.0     3
#  2000.0       2
#  50000.0      1
#  198.0        1
#  1500.0       1
#  750.0        1
#  3000.0       1
#  15000.0      1
#  300.0        1
# -500.0        1
#  499.0        1
#  25000.0      1
#  20000.0      1
#  150000.0     1
#  60000.0      1
# Name: amount, dtype: int64

# %%
supportsmoke = smokemerge[smokemerge.committee_position == "SUPPORT"]

# %%
supportsmoke
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 0    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 1    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 2    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 3    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 4    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 5    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 6    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 7    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 8    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 9    ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 10   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 11   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# ...

# %%
bigdonorsoppose = opposesmoke[opposesmoke.amount > 10000]

# %%
bigdonorsoppose.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 64 to 204
# Data columns (total 20 columns):
# ocd_prop_id                     9 non-null object
# calaccess_prop_id               9 non-null int64
# ccdc_prop_id                    9 non-null int64
# prop_name                       9 non-null object
# ccdc_committee_id               9 non-null int64
# calaccess_committee_id          9 non-null int64
# committee_name_x                9 non-null object
# committee_position              9 non-null object
# committee_name_y                9 non-null object
# calaccess_filing_id             9 non-null int64
# date_received                   9 non-null object
# contributor_lastname            9 non-null object
# contributor_firstname           1 non-null object
# contributor_city                9 non-null object
# contributor_state               9 non-null object
# contributor_zip                 9 non-null object
# contributor_employer            0 non-null object
# ...

# %%
bigdonorsoppose.head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 64   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 165  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 176  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 180  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 182  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
#
#      ccdc_prop_id                                          prop_name  \
# 64             76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 165            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 176            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 180            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 182            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 64                 422                 1386627
# ...

# %%
bigdonorsupport = supportsmoke[supportsmoke.amount > 10000]

# %%
bigdonorsoppose.head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 64   ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 165  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 176  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 180  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 182  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
#
#      ccdc_prop_id                                          prop_name  \
# 64             76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 165            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 176            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 180            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 182            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 64                 422                 1386627
# ...

# %%
supportsmoke.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 1  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 2  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 3  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
# 4  ocd-contest/d2dc34aa-0d9e-4a71-a40d-1aff71fcaf34            1383319
#
#    ccdc_prop_id                                          prop_name  \
# 0            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 1            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 2            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 3            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
# 4            76  PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                417                 1385745
# ...

# %%
bigdonorsupport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76 entries, 0 to 236
# Data columns (total 20 columns):
# ocd_prop_id                     76 non-null object
# calaccess_prop_id               76 non-null int64
# ccdc_prop_id                    76 non-null int64
# prop_name                       76 non-null object
# ccdc_committee_id               76 non-null int64
# calaccess_committee_id          76 non-null int64
# committee_name_x                76 non-null object
# committee_position              76 non-null object
# committee_name_y                76 non-null object
# calaccess_filing_id             76 non-null int64
# date_received                   76 non-null object
# contributor_lastname            76 non-null object
# contributor_firstname           15 non-null object
# contributor_city                76 non-null object
# contributor_state               76 non-null object
# contributor_zip                 76 non-null object
# ...

# %%
smokemerge.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending="False")
# Out:
#                                      committee_name_x      amount
# 9   PICO CALIFORNIA - YES ON 55, 56, AND 57 (NON P...    37941.12
# 2   CIVIC PARTICIPATION ACTION FUND - YES ON 57 (N...   188760.00
# 0   CALIFORNIA CALLS ACTION FUND (NONPROFIT 501(C)...   208760.00
# 5   MILLION VOTER PROJECT ACTION FUND - YES ON 55 ...   426035.55
# 1   CALIFORNIA STATEWIDE LAW ENFORCEMENT ASSOCIATI...   498096.00
# 8   OPEN PHILANTHROPY ACTION FUND YES ON 57 (NONPR...   600000.00
# 7   NO ON 57 - STOP EARLY RELEASE OF VIOLENT CRIMI...   790047.00
# 4   FWD.US (NONPROFIT 501(C)(4)) IN SUPPORT OF PRO...  1000000.00
# 6   MILLION VOTER PROJECT ACTION FUND - YES ON 55,...  2110000.00
# 3        FUND FOR POLICY REFORM (NONPROFIT 501(C)(4))  6140000.00
# 10  YES ON PROP. 57, CALIFORNIANS AND GOVERNOR BRO...  8097730.06

# %%
smokemerge.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname contributor_lastname     amount
# 103                THOMAS               STEYER  1750000.0
# 73                   MARK           ZUCKERBERG  1000000.0
# 28                 DUSTIN            MOSKOVITZ   600000.0
# 81               NICHOLAS             PRITZKER   100000.0
# 71               M. QUINN              DELANEY   100000.0
# 82              NICOLE A.             SHANAHAN    85000.0
# 70                M QUINN              DELANEY    75000.0
# 10                CAITLIN              HEISING    50000.0
# 30              ELIZABETH               SIMONS    50000.0
# 90                 ROBERT          DOWNEY, JR.    35000.0
# 98                  SUSAN               DOWNEY    35000.0
# 58                KAITLYN      TRIGGER KRIEGER    25000.0
# 107             THOMAS V.             MCKERNAN    20000.0
# 3                    ANNE                IRWIN    20000.0
# 1               ALEXANDRA     MALLICK-WILLIAMS    15000.0
# ...

# %%
smokemerge.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname contributor_lastname committee_position     amount
# 103                THOMAS               STEYER            SUPPORT  1750000.0
# 73                   MARK           ZUCKERBERG            SUPPORT  1000000.0
# 28                 DUSTIN            MOSKOVITZ            SUPPORT   600000.0
# 81               NICHOLAS             PRITZKER            SUPPORT   100000.0
# 71               M. QUINN              DELANEY            SUPPORT   100000.0
# 82              NICOLE A.             SHANAHAN            SUPPORT    85000.0
# 70                M QUINN              DELANEY            SUPPORT    75000.0
# 10                CAITLIN              HEISING            SUPPORT    50000.0
# 30              ELIZABETH               SIMONS            SUPPORT    50000.0
# 90                 ROBERT          DOWNEY, JR.            SUPPORT    35000.0
# 98                  SUSAN               DOWNEY            SUPPORT    35000.0
# ...

# %%
smokemerge.groupby(["committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#   committee_position       amount
# 1            SUPPORT  19307322.73
# 0             OPPOSE    790047.00
